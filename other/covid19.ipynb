# %%
import numpy as np
import pandas as pa

# %%
dataset = pa.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
data = pa.DataFrame(dataset)

# %%
euData = data[data["continent"] == "Europe"]
franceData = euData[euData["iso_code"] == "FRA"]
franceData.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 42319      FRA    Europe   France  2020-01-24          2.0        2.0
# 42320      FRA    Europe   France  2020-01-25          3.0        1.0
# 42321      FRA    Europe   France  2020-01-26          3.0        0.0
# 42322      FRA    Europe   France  2020-01-27          3.0        0.0
# 42323      FRA    Europe   France  2020-01-28          4.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 42319                 NaN           NaN         NaN                  NaN  ...
# 42320                 NaN           NaN         NaN                  NaN  ...
# 42321                 NaN           NaN         NaN                  NaN  ...
# 42322                 NaN           NaN         NaN                  NaN  ...
# 42323                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133808 entries, 0 to 133807
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    133808 non-null  object
#  1   continent                                   125269 non-null  object
#  2   location                                    133808 non-null  object
#  3   date                                        133808 non-null  object
#  4   total_cases                                 126445 non-null  float64
#  5   new_cases                                   126443 non-null  float64
#  6   new_cases_smoothed                          125400 non-null  float64
#  7   total_deaths                                115288 non-null  float64
#  8   new_deaths                                  115484 non-null  float64
# ...

# %%
casesData = franceData[["date", "new_cases", "new_cases_smoothed", "location"]]
casesData
# Out:
#              date  new_cases  new_cases_smoothed location
# 42319  2020-01-24        2.0                 NaN   France
# 42320  2020-01-25        1.0                 NaN   France
# 42321  2020-01-26        0.0                 NaN   France
# 42322  2020-01-27        0.0                 NaN   France
# 42323  2020-01-28        1.0                 NaN   France
# ...           ...        ...                 ...      ...
# 42977  2021-11-12     3887.0            8786.286   France
# 42978  2021-11-13    14676.0            9502.286   France
# 42979  2021-11-14    12506.0           10066.143   France
# 42980  2021-11-15     3307.0           10218.429   France
# 42981  2021-11-16    19884.0           11264.000   France
#
# [663 rows x 4 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X = np.linspace(0, len(casesData), len(casesData))
Y = casesData["new_cases"]

plt.plot(X, casesData["new_cases"], c="red")
plt.plot(X, casesData["new_cases_smoothed"], c="blue")
